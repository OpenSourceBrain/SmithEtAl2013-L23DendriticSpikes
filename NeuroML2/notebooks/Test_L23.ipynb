# %% [markdown]
# ## Plotting behaviour of L23 cell under steady current injection

# %%
import sys
# %matplotlib inline  

cell_file = '../L23_NoHotSpot.cell.nml'
cell_id = 'L23_NoHotSpot'

import warnings
warnings.simplefilter('ignore')

from pyneuroml.analysis import generate_current_vs_frequency_curve
    
    
curve = generate_current_vs_frequency_curve(cell_file, 
                                    cell_id, 
                                    custom_amps_nA =       [-0.11,-0.07,0,0.07,0.11,0.21,0.27,0.35], 
                                    analysis_duration =    1000, 
                                    pre_zero_pulse =       100,
                                    post_zero_pulse =      100,
                                    analysis_delay =       0,
                                    dt =                   0.025,
                                    simulator =            'jNeuroML_NEURON',
                                    plot_voltage_traces =  True,
                                    plot_if =              False,
                                    plot_iv =              False,
                                    temperature =          '35degC',
                                    title_above_plot =      True)
# Out:
# pyNeuroML >>> Generating an FI curve for cell L23_NoHotSpot in ../L23_NoHotSpot.cell.nml using jNeuroML_NEURON (-0.1nA->0.1nA; 0.01nA steps)
# pyNeuroML >>> Written LEMS Simulation iv_L23_NoHotSpot to file: LEMS_iv_L23_NoHotSpot.xml
# /usr/local/lib/python2.7/dist-packages/numpy/core/fromnumeric.py:2889: RuntimeWarning: Mean of empty slice.
#   out=out, **kwargs)
# /usr/local/lib/python2.7/dist-packages/numpy/core/_methods.py:80: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# pyNeuroML >>> Generating plot: Membrane potential traces for: ../L23_NoHotSpot.cell.nml
# /usr/lib/python2.7/dist-packages/simplejson/encoder.py:275: DeprecationWarning: Interpreting naive datetime as local 2017-04-19 11:58:08.232980. Please add timezone info to timestamps.
#   chunks = self.iterencode(o, _one_shot=True)

# %%
# Longer duration, more points 
    
curve = generate_current_vs_frequency_curve(cell_file, 
                                    cell_id, 
                                    start_amp_nA =         -0.1, 
                                    end_amp_nA =           0.5, 
                                    step_nA =              0.025, 
                                    analysis_duration =    2000, 
                                    pre_zero_pulse =       0,
                                    post_zero_pulse =      0,
                                    analysis_delay =       100,
                                    simulator =            'jNeuroML_NEURON',
                                    plot_voltage_traces =  False,
                                    plot_if =              True,
                                    plot_iv =              True,
                                    temperature =          '35degC',
                                    title_above_plot =      True)
# Out:
# pyNeuroML >>> Generating an FI curve for cell L23_NoHotSpot in ../L23_NoHotSpot.cell.nml using jNeuroML_NEURON (-0.1nA->0.5nA; 0.025nA steps)
# pyNeuroML >>> Written LEMS Simulation iv_L23_NoHotSpot to file: LEMS_iv_L23_NoHotSpot.xml
# pyNeuroML >>> Generating plot: Firing frequency versus injected current for: ../L23_NoHotSpot.cell.nml
# pyNeuroML >>> Generating plot: V at 2100ms versus I below threshold for: ../L23_NoHotSpot.cell.nml
# /usr/lib/python2.7/dist-packages/simplejson/encoder.py:275: DeprecationWarning: Interpreting naive datetime as local 2017-04-19 12:06:13.666704. Please add timezone info to timestamps.
#   chunks = self.iterencode(o, _one_shot=True)

# %%
from pyneuroml import pynml
pynml.run_jneuroml("", cell_file, '-png')
from IPython.display import Image
Image(filename=cell_file.replace('.nml','.png'),width=500)
# Out:
# /usr/lib/python2.7/dist-packages/simplejson/encoder.py:275: DeprecationWarning: Interpreting naive datetime as local 2017-04-19 12:31:15.817203. Please add timezone info to timestamps.
#   chunks = self.iterencode(o, _one_shot=True)
